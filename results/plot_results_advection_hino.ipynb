# %%
import jax
jax.config.update("jax_enable_x64", True)
import jax.numpy as jnp
import sys
sys.path.append('..')
import networks
from utils import *
from networks import *

# %%
import matplotlib.pyplot as plt
import scienceplots
import cmasher as cmr
plt.style.use('science')
cmap_pred = plt.get_cmap('cmr.wildfire')
cmap_error = plt.get_cmap('cmr.cosmic')

# %%
problem = "advection"
hino_or_hno = "HINO"
running_on = "local"
if running_on == "local":
    data_path = "C:/Users/eirik/OneDrive - NTNU/5. klasse/prosjektoppgave/eirik_prosjektoppgave/data/"
    checkpoint_path = "C:/Users/eirik/orbax/checkpoints/"
else:
    data_path = "/cluster/work/eirikaf/data/"
    checkpoint_path = "/cluster/work/eirikaf/checkpoints/"

# %%
data = jnp.load(data_path + problem + ".npz")
train_val_test = train_val_test_split(data["data"], 0.8, 0.1, 0.1)
scaled_data = jnp.load(data_path + problem + "_z_score.npz")

# %%
u_standardizer = GaussianStandardizer(train_val_test["train"])
x_standardizer = GaussianStandardizer(data["x"])
t_standardizer = GaussianStandardizer(data["t"])

# %%
a_train_s = scaled_data["a_train_s"]
u_train_s = scaled_data["u_train_s"]
a_val_s = scaled_data["a_val_s"]
u_val_s = scaled_data["u_val_s"]
a_test_s = scaled_data["a_test_s"]
u_test_s = scaled_data["u_test_s"]

x_train_s = scaled_data["x_train_s"]
t_train_s = scaled_data["t_train_s"]

x_test_s = scaled_data["x_test_s"] 
t_test_s = scaled_data["t_test_s"]

x_test = x_standardizer.decode(x_test_s)
t_test = t_standardizer.decode(t_test_s)

u_test = u_standardizer.decode(u_test_s)

# %%
networks = {
    #"deeponet": HINO_DON,
    "modified_deeponet": HINO_DON,
    #"fno_timestepping": FNOTimeStepping,
    #"fno1d": FNO1d,
    #"fno2d": FNO2d
}
models = {}
trainers = {}

for network_name, network in networks.items():
    trainers[network_name] = Trainer.from_checkpoint(checkpoint_path + f"{network_name}_{problem}_{hino_or_hno}", 
                                                 network)
    models[network_name] = trainers[network_name].model

# %%
pretty_names = {
    "deeponet": "HINODeepONet",
    "modified_deeponet": "ModifiedDeepONet",
    "fno_timestepping": "FNOTimeStepping",
    "fno1d": "FNO1d",
    "fno2d": "FNO2d"
}

# %%
model = models["modified_deeponet"]

xx, tt = jnp.meshgrid(x_train_s, t_train_s)
plt.imshow(vmap(model.u.u_t, (None, 0, 0))(a_test_s[0], xx.ravel(), tt.ravel()).reshape(xx.shape), aspect="auto", cmap=cmap_pred)
plt.colorbar()

# %%
model = models["modified_deeponet"]

plt.imshow(model.integrate(a_test_s[0], x_train_s, t_train_s), aspect="auto", cmap=cmap_pred)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 model = models["modified_deeponet"]
# ----> 3 plt.imshow(model.integrate(a_test_s[0], x_train_s, t_train_s), aspect="auto", cmap=cmap_pred)
#       4 plt.colorbar()
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:136, in HINO_DON.integrate(self, a, x, t)
#     134 solver = Tsit5()
#     135 saveat = SaveAt(ts=t)
# --> 136 solution = diffeqsolve(term,
#     137                        solver,
#     138                        t0=t[0],
#     139                        t1=t[-1],
#     140                        dt0=t[1]-t[0],
#     141                        y0=a,
#     142                        args=x,
#     143                        saveat=saveat)
#     144 return solution.ys
#
#     [... skipping hidden 15 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\diffrax\_integrate.py:1028, in diffeqsolve(terms, solver, t0, t1, dt0, y0, args, saveat, stepsize_controller, adjoint, event, max_steps, throw, progress_meter, solver_state, controller_state, made_jump, discrete_terminating_event)
#    1024 # Error checking
#    1025 if not _term_compatible(
#    1026     y0, args, terms, solver.term_structure, solver.term_compatible_contr_kwargs
#    1027 ):
# -> 1028     raise ValueError(
#    1029         "`terms` must be a PyTree of `AbstractTerms` (such as `ODETerm`), with "
#    1030         f"structure {solver.term_structure}"
#    1031     )
#    1033 if is_sde(terms):
#    1034     if not isinstance(solver, (AbstractItoSolver, AbstractStratonovichSolver)):
#
# ValueError: `terms` must be a PyTree of `AbstractTerms` (such as `ODETerm`), with structure <class 'diffrax._term.AbstractTerm'>

# %%
model = models["modified_deeponet"]

plt.imshow(model.integrate2(a_test_s[0][::4], x_train_s, t_train_s), aspect="auto", cmap=cmap_pred)
plt.colorbar()

# %%
plt.imshow(u_test[0]**2, aspect="auto", cmap=cmap_pred)

# %%
plt.imshow(vmap(model, (None, 0, 0))(a_test_s[0], xx.ravel(), tt.ravel()).reshape(xx.shape), aspect="auto", cmap=cmap_pred)
plt.colorbar()

# %%
plt.imshow(models["modified_deeponet"].u.predict_whole_grid(a_test_s[0], x_test_s, t_test_s), aspect="auto", cmap=cmap_pred)

# %% [markdown]
# ### Plot one prediction from the test set for t = 0, t $\approx$ 1, t $\approx$ 2, t $\approx$ 3

# %%
sample_idx = 88

u_preds = {}
for network_name, model in models.items():
    if network_name == "fno_timestepping":
        u_preds[network_name] = u_standardizer.decode(model.predict_whole_grid(a_test_s[sample_idx], x_test_s, t_test_s))
    else:
        t = t_test_s[t_test_s < 1] # time interval [0, 2) (use scaled time as input to model, hence t_test_s < 1)
        # prediction on [0, 2)
        u_pred1 = u_standardizer.decode(model.predict_whole_grid(a_test_s[sample_idx], x_test_s, t))
        # prediction on [1, 3) by using the prediction for t=1 as initial condition 
        u_pred2 = u_standardizer.decode(model.predict_whole_grid(u_pred1[t==0.5][0], x_test_s, t))
        
        # concatenate the predictions on [0, 2) and [2, 3)
        u_preds[network_name] = jnp.concatenate((u_pred1, u_pred2[t>=0.5]), axis=0)

u_gt = u_test[sample_idx]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       8 t = t_test_s[t_test_s < 1] # time interval [0, 2) (use scaled time as input to model, hence t_test_s < 1)
#       9 # prediction on [0, 2)
# ---> 10 u_pred1 = u_standardizer.decode(model.predict_whole_grid(a_test_s[sample_idx], x_test_s, t))
#      11 # prediction on [1, 3) by using the prediction for t=1 as initial condition
#      12 u_pred2 = u_standardizer.decode(model.predict_whole_grid(u_pred1[t==0.5][0], x_test_s, t))
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:110, in HINO_DON.predict_whole_grid(self, a, x, t)
#      99 """When we want to predict on the whole grid, we simply use the operator network's output, without the energy net.
#     100
#     101 Args:
#    (...)
#     107     u_pred (N+1, M+1): prediction at the given grid points.
#     108 """
#     109 xx, tt = jnp.meshgrid(x, t)
# --> 110 𝒢δℋ = self.multiple_query_points_one_a(a, xx.ravel(), tt.ravel())
#     112 return 𝒢δℋ.reshape(xx.shape)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:96, in HINO_DON.multiple_query_points_one_a(self, a, x, t)
#      95 def multiple_query_points_one_a(self, a, x, t):
# ---> 96     return vmap(self, (None, 0, 0))(a, x, t)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:992, in vmap.<locals>.vmap_f(*args, **kwargs)
#     989 axis_size_ = (axis_size if axis_size is not None else
#     990               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
#     991 try:
# --> 992   out_flat = batching.batch(
#     993       flat_fun, axis_name, axis_size_, in_axes_flat,
#     994       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#     995       spmd_axis_name=spmd_axis_name
#     996   ).call_wrapped(*args_flat)
#     997 except batching.SpecMatchError as e:
#     998   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:69, in HINO_DON.__call__(self, a, x, t)
#      66 dFdu_x = lambda x : grad(self.F, 1)(u(x), u_x(x)) # ∂F/∂u in original scale
#      67 δℋ = lambda x : dFdu(x) - grad(dFdu_x)(x)/(self.u.x_std + self.u.eps) # δℋ/δu in original scale
# ---> 69 𝒢δℋ =  -grad(δℋ)(x)/(self.u.x_std + self.u.eps)  # 𝒢 δℋ/δu in original scale
#      71 return 𝒢δℋ
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:462, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     460   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     461 if not has_aux:
# --> 462   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     463 else:
#     464   ans, vjp_py, aux = _vjp(
#     465       f_partial, *dyn_args, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:1962, in _vjp(fun, has_aux, *primals)
#    1960 if not has_aux:
#    1961   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1962   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    1963   out_tree = out_tree()
#    1964 else:
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:142, in vjp(traceable, primals, has_aux)
#     140 def vjp(traceable, primals, has_aux=False):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:681, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     679 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     680   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 681   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     682   assert not env
#     683   del main, fun, env
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:67, in HINO_DON.__call__.<locals>.<lambda>(x)
#      65 dFdu = lambda x : grad(self.F)(u(x), u_x(x)) # ∂F/∂u in original scale
#      66 dFdu_x = lambda x : grad(self.F, 1)(u(x), u_x(x)) # ∂F/∂u in original scale
# ---> 67 δℋ = lambda x : dFdu(x) - grad(dFdu_x)(x)/(self.u.x_std + self.u.eps) # δℋ/δu in original scale
#      69 𝒢δℋ =  -grad(δℋ)(x)/(self.u.x_std + self.u.eps)  # 𝒢 δℋ/δu in original scale
#      71 return 𝒢δℋ
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:462, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     460   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     461 if not has_aux:
# --> 462   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     463 else:
#     464   ans, vjp_py, aux = _vjp(
#     465       f_partial, *dyn_args, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:1962, in _vjp(fun, has_aux, *primals)
#    1960 if not has_aux:
#    1961   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1962   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    1963   out_tree = out_tree()
#    1964 else:
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:142, in vjp(traceable, primals, has_aux)
#     140 def vjp(traceable, primals, has_aux=False):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:681, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     679 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     680   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 681   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     682   assert not env
#     683   del main, fun, env
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:66, in HINO_DON.__call__.<locals>.<lambda>(x)
#      63 u_x = lambda x : self.u.u_x(a, x, t) # u_x in original scale
#      65 dFdu = lambda x : grad(self.F)(u(x), u_x(x)) # ∂F/∂u in original scale
# ---> 66 dFdu_x = lambda x : grad(self.F, 1)(u(x), u_x(x)) # ∂F/∂u in original scale
#      67 δℋ = lambda x : dFdu(x) - grad(dFdu_x)(x)/(self.u.x_std + self.u.eps) # δℋ/δu in original scale
#      69 𝒢δℋ =  -grad(δℋ)(x)/(self.u.x_std + self.u.eps)  # 𝒢 δℋ/δu in original scale
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\hino_DON.py:63, in HINO_DON.__call__.<locals>.<lambda>(x)
#      54 """The input and output of the HINO is the same as the input of the OperatorNet.
#      55 Input:
#      56     x: scalar
#    (...)
#      59     u_t(x,t): scalar, at x=x and t=t
#      60 """
#      62 u = lambda x : self.u.decode_u(self.u(a, x, t)) # u in original scale (function of x for ease of notation)
# ---> 63 u_x = lambda x : self.u.u_x(a, x, t) # u_x in original scale
#      65 dFdu = lambda x : grad(self.F)(u(x), u_x(x)) # ∂F/∂u in original scale
#      66 dFdu_x = lambda x : grad(self.F, 1)(u(x), u_x(x)) # ∂F/∂u in original scale
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\modified_deeponet.py:146, in ModifiedDeepONet.u_x(self, a, x, t)
#     145 def u_x(self, a, x, t):
# --> 146     return self.Dx(a, x, t)*(self.u_std+self.eps)/(self.x_std + self.eps)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\modified_deeponet.py:137, in ModifiedDeepONet.Dx(self, a, x, t)
#     136 def Dx(self, a, x, t):
# --> 137     return grad(self, 1)(a, x, t)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:392, in grad.<locals>.grad_f(*args, **kwargs)
#     389 @wraps(fun, docstr=docstr, argnums=argnums)
#     390 @api_boundary
#     391 def grad_f(*args, **kwargs):
# --> 392   _, g = value_and_grad_f(*args, **kwargs)
#     393   return g
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:462, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     460   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     461 if not has_aux:
# --> 462   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     463 else:
#     464   ans, vjp_py, aux = _vjp(
#     465       f_partial, *dyn_args, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\api.py:1962, in _vjp(fun, has_aux, *primals)
#    1960 if not has_aux:
#    1961   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1962   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    1963   out_tree = out_tree()
#    1964 else:
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:142, in vjp(traceable, primals, has_aux)
#     140 def vjp(traceable, primals, has_aux=False):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:681, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     679 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     680   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 681   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     682   assert not env
#     683   del main, fun, env
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File c:\Users\eirik\OneDrive - NTNU\5. klasse\prosjektoppgave\eirik_prosjektoppgave\results\..\networks\modified_deeponet.py:100, in ModifiedDeepONet.__call__(self, a, x, t)
#      97     y = jnp.multiply(T, B_E) + jnp.multiply(1 - T, T_E)
#      98     return (a, y), None
# --> 100 (a, y), _ = jax.lax.scan(f, (a, y), (self.intermediate_branch_layers, self.intermediate_trunk_layers))
#     102 # Compute the last layer outputs
#     103 B = self.last_branch_layer(a) # last layer of the branch network is not activated
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:316, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     314   in_flat = [*in_state, *in_carry, *in_ext]
#     315   num_carry += len(attrs_tracked)
# --> 316 out = scan_p.bind(*consts, *in_flat,
#     317                   reverse=reverse, length=length, jaxpr=jaxpr,
#     318                   num_consts=len(consts), num_carry=num_carry,
#     319                   linear=(False,) * (len(consts) + len(in_flat)),
#     320                   unroll=unroll,
#     321                   _split_transpose=_split_transpose)
#     322 if attrs_tracked:
#     323   out_state, out = split_list(out, [len(attrs_tracked)])
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:302, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     300   msg = f"Differentiation rule for '{primitive}' not implemented"
#     301   raise NotImplementedError(msg)
# --> 302 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     303 if primitive.multiple_results:
#     304   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:539, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#     534 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     535 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     536                          + init_linear + [True] * len(init_dot)
#     537                          + xs_linear + [True] * len(xs_dot))
# --> 539 out_flat = scan_p.bind(
#     540     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     541     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     542     num_consts=num_consts + len(consts_dot),
#     543     num_carry=num_carry + len(init_dot),
#     544     linear=jaxpr_jvp_linear, unroll=unroll,
#     545     _split_transpose=_split_transpose)
#     547 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     548 primals_out = carry + ys
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:210, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     208 def process_primitive(self, primitive, tracers, params):
#     209   if primitive in custom_partial_eval_rules:
# --> 210     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     211   else:
#     212     return self.default_process_primitive(primitive, tracers, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:650, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *tracers)
#     648 else:
#     649   linear_known = [False] * len(known_inputs)  # conservative!
# --> 650   out_known = scan_p.bind(
#     651       *known_inputs, reverse=reverse, length=length, jaxpr=jaxpr_known,
#     652       num_consts=len(jaxpr_known_consts), num_carry=num_carry - sum(carry_uk),
#     653       linear=tuple(linear_known), unroll=unroll,
#     654       _split_transpose=_split_transpose)
#     655   del linear_known
#     656 # Complete the known output by filling in forwarded values using fwds_known.
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:302, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     300   msg = f"Differentiation rule for '{primitive}' not implemented"
#     301   raise NotImplementedError(msg)
# --> 302 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     303 if primitive.multiple_results:
#     304   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:539, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#     534 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     535 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     536                          + init_linear + [True] * len(init_dot)
#     537                          + xs_linear + [True] * len(xs_dot))
# --> 539 out_flat = scan_p.bind(
#     540     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     541     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     542     num_consts=num_consts + len(consts_dot),
#     543     num_carry=num_carry + len(init_dot),
#     544     linear=jaxpr_jvp_linear, unroll=unroll,
#     545     _split_transpose=_split_transpose)
#     547 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     548 primals_out = carry + ys
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:210, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     208 def process_primitive(self, primitive, tracers, params):
#     209   if primitive in custom_partial_eval_rules:
# --> 210     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     211   else:
#     212     return self.default_process_primitive(primitive, tracers, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:650, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *tracers)
#     648 else:
#     649   linear_known = [False] * len(known_inputs)  # conservative!
# --> 650   out_known = scan_p.bind(
#     651       *known_inputs, reverse=reverse, length=length, jaxpr=jaxpr_known,
#     652       num_consts=len(jaxpr_known_consts), num_carry=num_carry - sum(carry_uk),
#     653       linear=tuple(linear_known), unroll=unroll,
#     654       _split_transpose=_split_transpose)
#     655   del linear_known
#     656 # Complete the known output by filling in forwarded values using fwds_known.
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\ad.py:302, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     300   msg = f"Differentiation rule for '{primitive}' not implemented"
#     301   raise NotImplementedError(msg)
# --> 302 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     303 if primitive.multiple_results:
#     304   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:539, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll, _split_transpose)
#     534 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     535 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     536                          + init_linear + [True] * len(init_dot)
#     537                          + xs_linear + [True] * len(xs_dot))
# --> 539 out_flat = scan_p.bind(
#     540     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     541     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     542     num_consts=num_consts + len(consts_dot),
#     543     num_carry=num_carry + len(init_dot),
#     544     linear=jaxpr_jvp_linear, unroll=unroll,
#     545     _split_transpose=_split_transpose)
#     547 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     548 primals_out = carry + ys
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:1218, in scan_bind(*args, **params)
#    1216   _scan_typecheck(True, *in_atoms, **params)
#    1217   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1218 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:210, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     208 def process_primitive(self, primitive, tracers, params):
#     209   if primitive in custom_partial_eval_rules:
# --> 210     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     211   else:
#     212     return self.default_process_primitive(primitive, tracers, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\lax\control_flow\loops.py:605, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *tracers)
#     602 other_pvals = [pe.PartialVal.unknown(aval)
#     603                for aval in jaxpr_known.in_avals[len(const_pvals):]]
#     604 with source_info_util.reset_name_stack():
# --> 605   jaxpr_known_, invar_pvals_out, jaxpr_known_consts = pe.trace_to_jaxpr_nounits(
#     606       lu.wrap_init(core.jaxpr_as_fun(jaxpr_known)), const_pvals + other_pvals,
#     607       instantiate=[True] * (len(out_uk) - sum(out_uk)) + [False] * num_res)
#     608 jaxpr_known = pe.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr_known_), ())
#     609 # The above trace_to_jaxpr_nounits call computed loop-invariant residuals
#     610 # (known values in invar_pvals_out) and also computed loop-invariant values
#     611 # needed by the new jaxpr_known (in jaxpr_known_consts, which replace the
#     612 # previous consts). We need to collect the computed inteisive residuals, and
#     613 # move corresponding intensive residual binders in jaxpr_unknown to the front.
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\interpreters\partial_eval.py:681, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     679 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     680   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 681   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     682   assert not env
#     683   del main, fun, env
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:260, in jaxpr_as_fun(closed_jaxpr, *args)
#     258 @curry
#     259 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
# --> 260   return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:508, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     505 traceback = eqn.source_info.traceback if propagate_source_info else None
#     506 with source_info_util.user_context(
#     507     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 508   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     509 if eqn.primitive.multiple_results:
#     510   map(write, eqn.outvars, ans)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:438, in Primitive.bind(self, *args, **params)
#     435 def bind(self, *args, **params):
#     436   assert (not config.enable_checks.value or
#     437           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 438   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:1381, in find_top_trace(xs)
#    1380 def find_top_trace(xs) -> Trace:
# -> 1381   top_tracer = max((x for x in xs if isinstance(x, Tracer)),
#    1382                     default=None, key=_get_trace_level)
#    1383   if top_tracer is not None:
#    1384     top_tracer._assert_live()
#
# File c:\Users\eirik\anaconda3\envs\prosjektoppgave\Lib\site-packages\jax\_src\core.py:1377, in _get_trace_level(t)
#    1373   else:
#    1374     return val
# -> 1377 def _get_trace_level(t: Tracer) -> int: return t._trace.level
#    1380 def find_top_trace(xs) -> Trace:
#    1381   top_tracer = max((x for x in xs if isinstance(x, Tracer)),
#    1382                     default=None, key=_get_trace_level)
#
# KeyboardInterrupt:

# %%
pred_color = "#7ab368"

time_indices = [0, jnp.where(t_test == 1)[0][0], jnp.where(t_test < 2)[0][-1], -1]
time_labels = [f't={t_test[time_indices[0]]:.2f}', f't={t_test[time_indices[1]]:.2f}', f't={t_test[time_indices[2]]:.2f}', f't={t_test[time_indices[3]]:.2f}']

fig, axes = plt.subplots(len(time_indices), len(u_preds), figsize=(15, 10))

y_min, y_max = u_gt.min(), u_gt.max()
for i, time_idx in enumerate(time_indices):
    for j, (model_name, u_pred) in enumerate(u_preds.items()):
        ax = axes[i, j]
        ax.plot(x_test, u_gt[time_idx, :], 'k--', label='Ground Truth')
        ax.plot(x_test, u_pred[time_idx, :], color=pred_color, label='Prediction')
        ax.set_ylim(y_min, y_max)  # Set the y-axis limits
        if i == 0:
            ax.set_title(pretty_names[model_name], fontsize=14)
        if j == 0:
            ax.set_ylabel(time_labels[i], fontsize=14)
        ax.tick_params(top=False,
                       left=False,
                       right=False, 
                       bottom=False, 
                       labelleft=False, 
                       labelbottom=False, 
                       which='both')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)

# Create a common legend
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=2, bbox_to_anchor=(0.5, 1.), fontsize='large')

# Add a title to the figure
fig.suptitle('Predictions on unseen initial condition for the advection equation', fontsize=18, x=0.5, y=1.05)

# Adjust space between subplots
plt.tight_layout()
plt.subplots_adjust(wspace=0.1, hspace=0.3)

plt.savefig("predictions/pred_advection.svg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 11
#       9 for i, time_idx in enumerate(time_indices):
#      10     for j, (model_name, u_pred) in enumerate(u_preds.items()):
# ---> 11         ax = axes[i, j]
#      12         ax.plot(x_test, u_gt[time_idx, :], 'k--', label='Ground Truth')
#      13         ax.plot(x_test, u_pred[time_idx, :], color=pred_color, label='Prediction')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 5))

for i, (model_name, u_pred) in enumerate(u_preds.items()):
    # First row: imshow of u_pred
    ax1 = axes[0, i]
    im1 = ax1.imshow(u_pred.T, aspect='auto', cmap=cmap_pred, extent=[t_test.min(), t_test.max(), x_test.min(), x_test.max()], origin='lower')
    ax1.set_title(pretty_names[model_name], fontsize=14)
    fig.colorbar(im1, ax=ax1)
    ax1.set_xlabel('t')
    ax1.set_ylabel('x')
    ax1.axvline(x=2, color='white', linestyle='--')  # Add dashed line for t_test == 2
    ax1.tick_params(
                top=False,
                right=False, 
                bottom=False, 
                left=False,
                labelleft=False, 
                labelbottom=False, 
                which='both')
    
    # Second row: imshow of u_pred - u_gt
    ax2 = axes[1, i]
    im2 = ax2.imshow(jnp.abs(u_pred - u_gt).T, aspect='auto', cmap=cmap_error, extent=[t_test.min(), t_test.max(), x_test.min(), x_test.max()], origin='lower')
    fig.colorbar(im2, ax=ax2)
    ax2.set_xlabel('t')
    ax2.set_ylabel('x')
    ax2.axvline(x=2, color='white', linestyle='--')
    ax2.tick_params(
            top=False,
            right=False, 
            bottom=False, 
            left=False,
            labelleft=False, 
            labelbottom=False, 
            which='both')

axes[0, 0].set_ylabel('Prediction', fontsize=14)
axes[1, 0].set_ylabel(r'Error, $|u_{\text{pred}} - u_{\text{gt}}|$', fontsize=14)

fig.suptitle('Predictions on unseen initial condition for the advection equation', fontsize=18, x=0.5, y=1)

plt.tight_layout()
plt.savefig("predictions/pred_advection_imshow.svg")
plt.show()

# %% [markdown]
# # Loss plot

# %%
fig, axes = plt.subplots(1, 5, figsize=(15, 5))
methods = list(trainers.keys())
train_color = '#bc5090'
val_color = '#ffa600'

for i, (model_name, trainer) in enumerate(trainers.items()):
        ax = axes[i]
        
        # Plot batch loss
        ax.plot(jnp.linspace(0, trainer.epochs_trained - 1, len(trainer.train_loss_history_batch)),
                trainer.train_loss_history_batch, color=train_color, alpha=0.3, label='Batch Train Loss')
        ax.plot(jnp.linspace(0, trainer.epochs_trained - 1, len(trainer.val_loss_history_batch)),
                trainer.val_loss_history_batch, color=val_color, alpha=0.3, label='Batch Val Loss')
        
        # Plot epoch loss
        ax.plot(jnp.arange(len(trainer.train_loss_history)), trainer.train_loss_history, 
                color=train_color, label='Epoch Train Loss')
        ax.plot(jnp.linspace(0, trainer.epochs_trained - 1, len(trainer.val_loss_history)), 
                trainer.val_loss_history, 
                color=val_color, label='Epoch Val Loss')
        
        ax.set_title(pretty_names[model_name], fontsize=14)
        ax.set_xlabel('Epoch', fontsize=14)
        ax.set_yscale('log')
        ax.tick_params(
                top=False,
                right=False, 
                which='both')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
    
axes[0].set_ylabel('Relative Loss', fontsize=14)   

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=4, bbox_to_anchor=(0.5, 1.), fontsize='large')

fig.suptitle('Loss History for the advection equation', fontsize=18, x=0.5, y=1.05)
plt.tight_layout()
#plt.savefig("loss/loss_kdv.svg")
plt.show()

# %% [markdown]
# # Table with performance information

# %%
def test_relative_error(u_pred, u_test):    
    batch_size = u_test.shape[0] 
    u_norms = jnp.linalg.norm(u_test.reshape(batch_size,-1), 2, 1)
    diff_norms = jnp.linalg.norm((u_test - u_pred).reshape(batch_size,-1), 2, 1)
        
    loss = jnp.mean(diff_norms/u_norms)
    return loss

def test_mse(u_pred, u_test):    
    #compute the mse
    mse = jnp.mean((u_test - u_pred)**2)
    return mse

# %%
# Initialize lists to store the results
method_names = []
param_counts = []
times_per_epoch = []
epochs_trained = []
relative_errors = []
mses = []

t = t_test_s[t_test_s < 1]
u_test_without_extrapolation = u_test[:,t_test_s < 1]
# Iterate over each method and compute the required metrics
for method_name, trainer in trainers.items():    
    model = models[method_name]
    method_names.append(pretty_names[method_name])
    param_counts.append(param_count(model))
    times_per_epoch.append(trainer.time_trained / trainer.epochs_trained)
    epochs_trained.append(trainer.epochs_trained)
    
    u_pred = u_standardizer.decode(vmap(eqx.filter_jit(model.predict_whole_grid), (0, None, None))(a_test_s, x_test_s, t))
    relative_errors.append(test_relative_error(u_pred, u_test_without_extrapolation))
    mses.append(test_mse(u_pred, u_test_without_extrapolation))

# Create a pandas dataframe to store the results
results_df = pd.DataFrame({
    'Method': method_names,
    '# Parameters': param_counts,
    'Time per Epoch (s)': times_per_epoch,
    'Epochs Trained': epochs_trained,
    'Relative Error': relative_errors,
    'MSE': mses
})

results_df.to_csv("performance_metrics/performance_metrics_kdv.csv", index=False)
